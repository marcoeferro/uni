# %% [markdown]
# # Introduccion.
#
# Vamos a trabajar con el dataset de condicion habitacional por Provincia.
# ## Se van a trabajar los siguientes puntos:
#
#
# 1.   Importacion de librerias
# 2.   Carga de datasets
# 3.   Lectura de datasets en xlsx y transformacion a dataframe
# 4.   Analisis de dataframe
# 5.   Borrado de filas y/o columnas
# 6.   Visualizacion de estadisticas generales
# 7.   Manejo de loc e iloc para identificar posicion de filas y /o columnas
# 8.   Utilizacion de filtros para responder preguntas sobre el dataframe

# %% [markdown]
# ### 1. Carga de datos
#
# a. Abrir el dataset (condicion_habitacional.xlsx).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e153085c-7809-45db-9952-47f75e6b9a49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e153085c-7809-45db-9952-47f75e6b9a49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_excel ('condicion_habitacional.xlsx', sheet_name = "Cuadro 1" )
data
# Out:
#                                          Jurisdicción  \
# 0                                               Total
# 1                     Ciudad Autónoma de Buenos Aires
# 2                                        Buenos Aires
# 3                   24 partidos del Gran Buenos Aires
# 4   Resto de partidos de la provincia\nde Buenos A...
# 5                                           Catamarca
# 6                                               Chaco
# 7                                              Chubut
# 8                                             Córdoba
# 9                                          Corrientes
# 10                                         Entre Ríos
# 11                                            Formosa
# 12                                              Jujuy
# 13                                           La Pampa
# 14                                           La Rioja
# 15                                            Mendoza
# ...

# %%
data.columns
# Out:
# Index(['Jurisdicción', 'Pisos con revestimiento',
#        'Agua por cañería dentro     de la vivienda',
#        'Agua para beber y cocinar por red pública',
#        'Baño o letrina dentro de la vivienda', 'Dos o más baños',
#        'Baño con inodoro con arrastre de agua',
#        'Desagüe del inodoro del baño a red pública',
#        'Gas de red o electricidad para cocinar', 'Vivienda propia', 'Internet',
#        'Celular con internet', 'Computadora, tablet, etc.'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=44, step=1)

# %%
data.drop(data.index[27:44], inplace=True)
#data.drop([42,43], axis=0, inplace=True)

# %%
data
# Out:
#                                          Jurisdicción  \
# 0                                               Total
# 1                     Ciudad Autónoma de Buenos Aires
# 2                                        Buenos Aires
# 3                   24 partidos del Gran Buenos Aires
# 4   Resto de partidos de la provincia\nde Buenos A...
# 5                                           Catamarca
# 6                                               Chaco
# 7                                              Chubut
# 8                                             Córdoba
# 9                                          Corrientes
# 10                                         Entre Ríos
# 11                                            Formosa
# 12                                              Jujuy
# 13                                           La Pampa
# 14                                           La Rioja
# 15                                            Mendoza
# ...

# %%
data_sin_jurisdiccion = data.drop('Jurisdicción', axis=1)
data_sin_jurisdiccion

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Jurisdicción                                27 non-null     object
#  1   Pisos con revestimiento                     27 non-null     float64
#  2   Agua por cañería dentro     de la vivienda  27 non-null     float64
#  3   Agua para beber y cocinar por red pública   27 non-null     float64
#  4   Baño o letrina dentro de la vivienda        27 non-null     float64
#  5   Dos o más baños                             27 non-null     float64
#  6   Baño con inodoro con arrastre de agua       27 non-null     float64
#  7   Desagüe del inodoro del baño a red pública  27 non-null     float64
#  8   Gas de red o electricidad para cocinar      27 non-null     float64
# ...

# %% [markdown]
# Si deseo cambiar el orden de las columnas se puede utilizar **metodo reindex**

# %%
# data = data.reindex(columns=['Internet ',' Vivienda propia','Jurisdicción','Pisos con revestimiento','...','....'])

# %%
data.shape
# Out:
# (27, 13)

# %% [markdown]
# **Visualizar** 2 columnas selecionadas. Solo las 5 primeras.

# %%
data[['Internet', 'Vivienda propia']]
# Out:
#     Internet  Vivienda propia
# 0       78.0             65.5
# 1       90.6             52.9
# 2       82.1             67.3
# 3       82.8             68.3
# 4       80.9             65.9
# 5       66.8             77.8
# 6       64.0             75.0
# 7       79.0             61.0
# 8       78.7             58.7
# 9       59.1             70.3
# 10      76.0             66.4
# 11      57.5             73.1
# 12      68.4             73.7
# 13      85.8             64.5
# 14      77.2             71.8
# 15      76.5             60.6
# 16      63.9             72.1
# 17      78.7             61.9
# 18      76.6             62.0
# 19      65.1             70.2
# 20      64.4             63.4
# 21      78.9             62.8
# 22      86.0             57.8
# 23      78.6             65.5
# 24      49.5             83.7
# 25      83.9             55.9
# 26      66.3             73.7

# %% [markdown]
# **loc** selecciona filas y columnas con etiquetas específicas

# %%
data.loc[15,'Jurisdicción']
# Out:
# 'Mendoza'

# %%
data.loc[[15], ['Jurisdicción', 'Internet']]
# Out:
#    Jurisdicción  Internet
# 15      Mendoza      76.5

# %%
data.loc[[15,18], ['Jurisdicción', 'Internet']]
# Out:
#    Jurisdicción  Internet
# 15      Mendoza      76.5
# 18    Río Negro      76.6

# %%
data.loc[15:18, 'Jurisdicción' : 'Agua para beber y cocinar por red pública']
# Out:
#    Jurisdicción  Pisos con revestimiento  \
# 15      Mendoza                     88.8
# 16     Misiones                     86.1
# 17      Neuquén                     91.2
# 18    Río Negro                     92.0
#
#     Agua por cañería dentro     de la vivienda  \
# 15                                        94.1
# 16                                        87.2
# 17                                        95.4
# 18                                        94.7
#
#     Agua para beber y cocinar por red pública
# 15                                       93.1
# 16                                       80.4
# 17                                       93.2
# 18                                       92.7

# %% [markdown]
# **iloc** selecciona filas y columnas en posiciones enteras específicas

# %%
data.iloc[10,1]
# Out:
# 87.9

# %%
data.iloc[[10,11],[0,1]]
# Out:
#    Jurisdicción  Pisos con revestimiento
# 10   Entre Ríos                     87.9
# 11      Formosa                     61.9

# %%
data.iloc[10:13, -3:]
# Out:
#     Internet  Celular con internet  Computadora, tablet, etc.
# 10      76.0                  87.9                       57.4
# 11      57.5                  80.7                       38.1
# 12      68.4                  83.9                       47.6

# %%
data.mean()
# Out:
# <ipython-input-61-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Pisos con revestimiento                       84.281481
# Agua por cañería dentro     de la vivienda    90.696296
# Agua para beber y cocinar por red pública     88.385185
# Baño o letrina dentro de la vivienda          92.492593
# Dos o más baños                               22.772611
# Baño con inodoro con arrastre de agua         90.677778
# Desagüe del inodoro del baño a red pública    62.977778
# Gas de red o electricidad para cocinar        52.614815
# Vivienda propia                               66.733333
# Internet                                      73.900000
# Celular con internet                          88.344444
# ...

# %%
data['Dos o más baños'].min() , data['Dos o más baños'].max()
# Out:
# (16.8, 36.693510177326935)

# %% [markdown]
# Pandas provee numerosos métodos para realizar estadísticas sobre los datos tanto en series como en dataframes. Por defecto, estos métodos ignoran los missing values, no teniéndolos encuenta a la hora de realizar los cálculos. Si se usa el parámetro skipna = False los valores NaN se propagan al resultado final.
# Cuando se trabaja con un dataframe, estas funciones se calculan por columna y sólo las que tienen números y devuelven una serie.
# Entre estos métodos podemos encontrar: sum, mean, std, var,mode, median, count, min, max, prod

# %%
data.describe()
# Out:
#        Pisos con revestimiento  Agua por cañería dentro     de la vivienda  \
# count                27.000000                                   27.000000
# mean                 84.281481                                   90.696296
# std                   9.652622                                    7.642064
# min                  61.900000                                   69.200000
# 25%                  77.350000                                   88.100000
# 50%                  87.400000                                   93.300000
# 75%                  91.200000                                   95.550000
# max                  97.600000                                   98.700000
#
#        Agua para beber y cocinar por red pública  \
# count                                  27.000000
# mean                                   88.385185
# std                                     7.095649
# min                                    75.200000
# ...

# %%
data['Baños'] = data['Baño con inodoro con arrastre de agua'] + data['Baño o letrina dentro de la vivienda']
data
# Out:
#                                          Jurisdicción  \
# 0                                               Total
# 1                     Ciudad Autónoma de Buenos Aires
# 2                                        Buenos Aires
# 3                   24 partidos del Gran Buenos Aires
# 4   Resto de partidos de la provincia\nde Buenos A...
# 5                                           Catamarca
# 6                                               Chaco
# 7                                              Chubut
# 8                                             Córdoba
# 9                                          Corrientes
# 10                                         Entre Ríos
# 11                                            Formosa
# 12                                              Jujuy
# 13                                           La Pampa
# 14                                           La Rioja
# 15                                            Mendoza
# ...

# %% [markdown]
# Tambien es posible seleccionar **Filtros**

# %%
# calcular el cantidad de pisos con revestimiento solo en el caso de de que internet sea mayos a 85
data.loc[data['Internet']> 85].count()
# Out:
# Jurisdicción                                  3
# Pisos con revestimiento                       3
# Agua por cañería dentro     de la vivienda    3
# Agua para beber y cocinar por red pública     3
# Baño o letrina dentro de la vivienda          3
# Dos o más baños                               3
# Baño con inodoro con arrastre de agua         3
# Desagüe del inodoro del baño a red pública    3
# Gas de red o electricidad para cocinar        3
# Vivienda propia                               3
# Internet                                      3
# Celular con internet                          3
# Computadora, tablet, etc.                     3
# Baños                                         3
# dtype: int64

# %%
# calcular el promedio de pisos con revestimiento solo en el caso de de que internet sea mayos a 85
data.loc[data['Internet']> 85, 'Pisos con revestimiento'].mean()
# Out:
# 96.26666666666665

# %%
# calcular la cantidad de casos para cuando internet sea mayor a 65 y ademas Vivienda propia sea mayor a 30
data.loc[(data['Internet']> 65) & (data['Vivienda propia'] > 30)].count()
# Out:
# Jurisdicción                                  21
# Pisos con revestimiento                       21
# Agua por cañería dentro     de la vivienda    21
# Agua para beber y cocinar por red pública     21
# Baño o letrina dentro de la vivienda          21
# Dos o más baños                               21
# Baño con inodoro con arrastre de agua         21
# Desagüe del inodoro del baño a red pública    21
# Gas de red o electricidad para cocinar        21
# Vivienda propia                               21
# Internet                                      21
# Celular con internet                          21
# Computadora, tablet, etc.                     21
# Baños                                         21
# dtype: int64

# %%
# calcular el promedio de pisos con revestimiento solo en el caso de de que internet sea mayos a 65 y ademas Vivienda propia sea mayor a 30
data.loc[(data['Internet']> 65) & (data['Vivienda propia'] > 30) , 'Pisos con revestimiento'].mean()
# Out:
# 87.41904761904762

# %% [markdown]
# Borrado de filas o columnas utilizando el metodo **drop**

# %%
data.drop([0], axis=0, inplace=True)

# %%
data
# Out:
#                                          Jurisdicción  \
# 1                     Ciudad Autónoma de Buenos Aires
# 2                                        Buenos Aires
# 3                   24 partidos del Gran Buenos Aires
# 4   Resto de partidos de la provincia\nde Buenos A...
# 5                                           Catamarca
# 6                                               Chaco
# 7                                              Chubut
# 8                                             Córdoba
# 9                                          Corrientes
# 10                                         Entre Ríos
# 11                                            Formosa
# 12                                              Jujuy
# 13                                           La Pampa
# 14                                           La Rioja
# 15                                            Mendoza
# 16                                           Misiones
# ...

# %%
data_sin_jurisdiccion = data.drop('Jurisdicción', axis=1)
data_sin_jurisdiccion
# Out:
#     Pisos con revestimiento  Agua por cañería dentro     de la vivienda  \
# 1                      97.6                                        98.7
# 2                      87.4                                        93.3
# 3                      85.6                                        92.5
# 4                      90.0                                        94.5
# 5                      77.0                                        90.2
# 6                      70.4                                        74.8
# 7                      94.1                                        96.3
# 8                      91.2                                        95.8
# 9                      70.7                                        87.1
# 10                     87.9                                        95.7
# 11                     61.9                                        72.4
# 12                     72.6                                        88.2
# ...
