# %% [markdown]
# # Resolución Clase 7. Pandas. Parte 1.
# <img  src="logoeica.jpeg" high=50px width=70px align="left" >

# %%
#importa numpy
import numpy as np
#importa pandas
import pandas as pd

# %%
serie = pd.Series(data = [1,2,3, 4, 6.7],

index=['primero', 'segundo' ,'tercero', 'cuarto', 'quinto'])

# %%
serie
# Out:
# primero    1.0
# segundo    2.0
# tercero    3.0
# cuarto     4.0
# quinto     6.7
# dtype: float64

# %%
type(serie)
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame(data = [1,2,3, 4, 6.7],

index=['primero', 'segundo' ,'tercero', 'cuarto', 'quinto'])

# %%
df
# Out:
#            0
# primero  1.0
# segundo  2.0
# tercero  3.0
# cuarto   4.0
# quinto   6.7

# %%
df.index
# Out:
# Index(['primero', 'segundo', 'tercero', 'cuarto', 'quinto'], dtype='object')

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %% [markdown]
# Pandas nos facilita con varias funciones para leer archivos. Entre ellas podemos encontrar:
# .read_csv(): lee archivos csv como DataFrame
# .read_json(): lee archivos json como DataFrame
# .read_excel(): leer archivos excel como DataFrame
#
# Para conocer más funciones que ayuden a leer archivos, consulta acá (https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)
#
# Nosotros vamos a usar .read_csv() (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).

# %% [markdown]
# Los archivos csv son un tipo de documento en formato abierto sencillo para representar datos en forma de
# tabla, en las que las columnas se separan por comas (o punto y coma) y las filas por saltos de línea. Es uno de
# los formatos más utilizados en Data Science.
#
# La sintaxis para poder leer un archivo csv es:
# df = pd.read_csv('nombredelarchivo.csv', delimiter=',')
# Aunque muchas veces se omite el delimiter si el archivo esta separado por comas.
#
# Vamos a trabajar con el archivo StudentsPerformance.csv (se envio junto a este archivo).
# Es usual descargar el archivo csv en la misma carpeta en la que trabajas con el jupyter notebook. De esta
# manera, no tendras que especificar el path a tu archivo.

# %% [markdown]
# 1) Lee el archivo csv StudentsPerformace usando pandas. Guardalo en una variable llamada students.

# %%
#cargamos nuestro archivo de estudiantes en memoria
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7459a3a7-6a12-4cb6-b78b-a4b805dac05f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7459a3a7-6a12-4cb6-b78b-a4b805dac05f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
students = pd.read_csv("student-por.csv")

# %%
pd.options.display.max_rows = 20 # esta linea me muestra solo 10 filas , si lo cambio por 649 , me muestra todas las filas
students.tail(7)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 642     MS   F   17       U     GT3       T     4     3   teacher     other
# 643     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 642  ...      5        5      4     1     1      1        0   6   9  11
# 643  ...      4        4      3     2     2      5        4   7   9  10
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# ...

# %%
students.index
# Out:
# RangeIndex(start=0, stop=649, step=1)

# %%
students.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# 2) ¿Que tipo de estructura de datos contiene la variable students? Hint: Usa type

# %%
type(students)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# 3) ¿Cuantas filas y columnas tiene students? Para contestar esta pregunta, pandas tiene la funcion .shape.
# Su sintaxis es la siguiente: df.shape (df debe ser reemplazado por el nombre de tu DataFrame).

# %%
students.shape
# Out:
# (649, 33)

# %% [markdown]
# 3) ¿Cual es el nombre de las columnas contenidas en students? Para esto, pandas tiene el atributo
# .columns.

# %%
students.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# 4) Inspecciona las primeras 10 filas de students usando la función .head(). Dentro de esta función podemos
# colocar un numero. Este numero nos dira cuantas filas queremos observar.

# %%
students.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# ...

# %% [markdown]
# 5) Ahora inspecciona las 10 ultimas usando .tail(). También podemos indicar el número de filas que
# queremos observar.

# %%
students.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 639     MS   M   19       R     GT3       T     1     1     other  services
# 640     MS   M   18       R     GT3       T     4     2     other     other
# 641     MS   F   18       R     GT3       T     2     2   at_home     other
# 642     MS   F   17       U     GT3       T     4     3   teacher     other
# 643     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# ...

# %% [markdown]
# 6) ¿Que tipos de datos contiene cada una de las columnas de students? Para esto, utiliza el atributo
# .dtypes.

# %%
students.dtypes
# Out:
# school      object
# sex         object
# age          int64
# address     object
# famsize     object
#              ...
# health       int64
# absences     int64
# G1           int64
# G2           int64
# G3           int64
# Length: 33, dtype: object

# %% [markdown]
# 7) ¿Como accedemos a una fila o a una columa de un DataFrame?

# %% [markdown]
# Una de las maneras de acceder a una columna es especificando el nombre de la misma. Por ejemplo,
# df['nombre_columna'].

# %% [markdown]
# Accede a la columna age de students.

# %%
students['age']
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 644    19
# 645    18
# 646    18
# 647    17
# 648    18
# Name: age, Length: 649, dtype: int64

# %%
students.age
# Out:
# 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 644    19
# 645    18
# 646    18
# 647    17
# 648    18
# Name: age, Length: 649, dtype: int64

# %% [markdown]
# Otra manera de acceder es usando dos funciones .loc[] y .iloc[].
#
# 1. iloc[1:m, 1:n]: Se usa para seleccionar filas basadas en su posición de 1 a m filas y de 1 a n
# columnas.

# %%
#seleccionar las dos primeras filas y 3 columnas
students.iloc[:2, :3]
# Out:
#   school sex  age
# 0     GP   F   18
# 1     GP   F   17

# %%
#o tambien se usa para las dos primeras filas y todas sus columnas
students.iloc[:2,]
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1  G2  G3
# 0      4        3      4     1     1      3        4  0  11  11
# 1      5        3      3     1     1      3        2  9  11  11
#
# [2 rows x 33 columns]

# %%
#Selecciona los datos entre la decima y vigesima fila.
students.iloc[10:21]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# 11     GP   F   15       U     GT3       T     2     1  services     other
# 12     GP   M   15       U     LE3       T     4     4    health  services
# 13     GP   M   15       U     GT3       T     4     3   teacher     other
# 14     GP   M   15       U     GT3       A     2     2     other     other
# ..    ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 16     GP   F   16       U     GT3       T     4     4  services  services
# 17     GP   F   16       U     GT3       T     3     3     other     other
# 18     GP   M   17       U     GT3       T     3     2  services  services
# 19     GP   M   16       U     LE3       T     4     3    health     other
# 20     GP   M   15       U     GT3       T     4     3   teacher     other
#
# ...

# %%
#Selecciona las dos primeras columnas
students.iloc[:, :2]
# Out:
#     school sex
# 0       GP   F
# 1       GP   F
# 2       GP   F
# 3       GP   F
# 4       GP   F
# ..     ...  ..
# 644     MS   F
# 645     MS   F
# 646     MS   F
# 647     MS   M
# 648     MS   M
#
# [649 rows x 2 columns]

# %% [markdown]
# 2.  .loc[[nombre_fila], [nombre_columna]]. Se usa para seleccionar filas o columnas basadas en
# su nombre

# %%
#Selecciona la fila por nombre 1, o sea con indice igual a 1
students.loc[1]
# Out:
# school       GP
# sex           F
# age          17
# address       U
# famsize     GT3
#            ...
# health        3
# absences      2
# G1            9
# G2           11
# G3           11
# Name: 1, Length: 33, dtype: object

# %%
#Corre el codigo y observa que devuelve
students.loc[[1,20,3,4,5],['age','famsize']]
# Out:
#     age famsize
# 1    17     GT3
# 20   15     GT3
# 3    15     GT3
# 4    16     GT3
# 5    16     LE3

# %% [markdown]
# A veces queremos seleccionar filas que cumplan con ciertas condiciones, donde el valor de una columna en
# esa fila sea igual, mayor o menor que un valor.
#
# Para esto tenemos que usar una sintaxis especial.
# Vamos a construirla de a poco.
# Imaginemos que tenemos un DataFrame df con las columnas col1, col2 y col3.
# Queremos seleccionar solo aquellas filas donde col1 sea mayor a 10.
# Para eso diremos que queremos df['col1'] > 10 (La columna col1 debe ser mayor a 10).
#
# Ahora si corremos este codigo, veremos que devuelve valores booleanos. O sea devolvera False para aquellos valores que sean menores o iguales a 10 y True para los que sean mayores a 10.
# O sea que tenemos que agregar algo mas para poder seleccionar las columnas.
# Esta lista de valores booleanos se llama mascara booleana.
#
# ¿Que significa? Que si yo le paso estos valores a pandas, pandas interpretara que debe conservar aquellos valores donde tiene True y descartar donde tiene False.

# %% [markdown]
# Por eso, para filtrar filas en base a estas condiciones escribimos:

# %% [markdown]
# df[df['col1] > 10]

# %% [markdown]
# Esto significa primero fijese en que filas de df, la columna col1 es mayor a 10. Luego, selecciona solo aquellas
# filas donde esta condicion sea True.

# %%
#Selecciona solo las filas donde G1 sea mayor a 17
students[students['G1'] > 17]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# 332     GP   F   18       U     GT3       T     2     2   at_home   at_home
# 338     GP   F   17       R     LE3       T     3     1  services     other
# 344     GP   M   18       U     LE3       T     4     4   teacher   teacher
# 349     GP   F   17       U     GT3       T     3     2    health    health
# 594     MS   F   18       U     GT3       T     4     4   teacher   teacher
# 606     MS   F   17       U     GT3       T     4     2   teacher     other
# 617     MS   F   18       U     LE3       T     1     1   at_home  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 113  ...      3        5      2     1     1      3       10  18  17  18
# 332  ...      4        3      3     1     2      2        0  18  18  18
# ...

# %%
#Selecciona solo las filas donde Mjob sea igual a teacher
students[students['Mjob'] == 'teacher']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 10      GP   F   15       U     GT3       T     4     4  teacher    health
# 13      GP   M   15       U     GT3       T     4     3  teacher     other
# 20      GP   M   15       U     GT3       T     4     3  teacher     other
# 22      GP   M   16       U     LE3       T     4     2  teacher     other
# 29      GP   M   16       U     GT3       T     4     4  teacher   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 633     MS   F   18       R     LE3       T     4     4  teacher  services
# 636     MS   M   18       U     GT3       T     4     4  teacher   teacher
# 642     MS   F   17       U     GT3       T     4     3  teacher     other
# 643     MS   F   18       R     GT3       T     4     4  teacher   at_home
# 645     MS   F   18       U     LE3       T     3     1  teacher  services
#
# ...

# %%
#Selecciona solo aquellas filas donde address sea distinto a U
students[students['address']!='U']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 24      GP   F   15       R     GT3       T     2     4  services   health
# 32      GP   M   15       R     GT3       T     4     3   teacher  at_home
# 37      GP   M   16       R     GT3       A     4     4     other  teacher
# 38      GP   F   15       R     GT3       T     3     4  services   health
# 39      GP   F   15       R     GT3       T     2     2   at_home    other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...      ...
# 640     MS   M   18       R     GT3       T     4     2     other    other
# 641     MS   F   18       R     GT3       T     2     2   at_home    other
# 643     MS   F   18       R     GT3       T     4     4   teacher  at_home
# 644     MS   F   19       R     GT3       T     2     3  services    other
# 648     MS   M   18       R     LE3       T     3     2  services    other
#
# ...

# %%
#Muestra los valores de edad para aquellos estudiantes que tengan G3 mayor a G1
students[students['G3'] > students['G1']]['age']
# Out:
# 0      18
# 1      17
# 4      16
# 5      16
# 7      17
#        ..
# 641    18
# 642    17
# 643    18
# 645    18
# 648    18
# Name: age, Length: 344, dtype: int64

# %%
#Selecciona aquellos estudiantes que posean G1 Y G2 mayores a 12
students[(students['G1']>12)&(students['G2']>12)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 14      GP   M   15       U     GT3       A     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 634     MS   F   18       U     GT3       T     3     3     other     other
# 636     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 638     MS   M   17       U     GT3       T     2     3     other  services
# 641     MS   F   18       R     GT3       T     2     2   at_home     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
#
# ...

# %% [markdown]
# ### Missing Values o Valores faltantes
#
# Los valores faltantes son un problema muy grande a la hora de visualizar y limpiar datos así como también a la
# hora de entrenar un modelo.
# Uno de los pasos obligados de cualquier exploración de datos es evaluar la presencia de estos valores.
#
# Como manejar estos datos faltantes es un gran desafio. La mayoría de las veces no queremos eliminar esos
# valores porque significaría perder información valiosa en otros features.
#
# Los valores faltantes estan codificados normalemente como NaN. Esto no es un string, sino que es un valor
# especial de NumPy que es tratado como un flotante.
#
# Otra forma de encontrar un dato faltante es de la forma None (objeto de Python que representa ausencia de dato)
#
# Para chequear si tenemos valores faltantes podemos usar la función .isnull(). Esto nos devuelve una nueva
# DataFrame en la cual tendremos el valor False si no es faltante y True si ese valor es faltante.

# %%
#Utilice .isnull() para ver que ocurre
students.isnull()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 644   False  False  False    False    False    False  False  False  False
# 645   False  False  False    False    False    False  False  False  False
# 646   False  False  False    False    False    False  False  False  False
# 647   False  False  False    False    False    False  False  False  False
# 648   False  False  False    False    False    False  False  False  False
#
#       Fjob  ...  famrel  freetime  goout   Dalc   Walc  health  absences  \
# ...

# %%
#Prueba usar .isnull().sum() sobre tu dataframe para ver que devuelve
students.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#Elimina todas las filas que tengan valores faltantes. No te olvides de poner inplace=True dentro de la función.
students.dropna(inplace=True)

# %% [markdown]
# Una manera de ver facilmente algunos detalles estadisticos de cada columna de un DataFrame es usando la
# fución .describe().

# %%
#Usa la funcion .describe() sobre students y describe que informacion estadistica proporciona
students.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %% [markdown]
# Tambien es posible visualizar, por ejemplo, el promedio de una columna. Para esto pandas usa la función de
# numpy, pero provee la misma sintaxis que las demás funciones. Por ejemplo, si queremos calcular el promedio
# de la columna col1 del DataFrame df usamos df['col1'].mean().

# %%
#Calcula el promedio de la columna math score de students
students['studytime'].mean()
# Out:
# 1.9306625577812018

# %% [markdown]
# También podemos usar funciones como .min(), .max(), .median(), .std().

# %%
#Calcula el minimo y maximo valor, la mediana y el desvio estandard en la columna stdytime de students
students['studytime'].min()
# Out:
# 1

# %%
students['studytime'].max()
# Out:
# 4

# %%
students['studytime'].median()
# Out:
# 2.0

# %%
students['studytime'].std()
# Out:
# 0.8295095746366191

# %%
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   romantic famrel  freetime  Dalc  Walc health absences  G1  G2  G3
# 0       no      4         3     1     1      3        4   0  11  11
# 1       no      5         3     1     1      3        2   9  11  11
# 2       no      4         3     2     3      3        6  12  13  12
# 3      yes      3         2     1     1      5        0  14  14  14
# 4       no      4         3     1     2      5        0  11  13  13
#
# [5 rows x 32 columns]

# %%
#elimina una columna (axis=1) o una fila (axis=0) que cumpla con la condicion que le ponga
students.drop('Walc', axis=1, inplace=True)

# %%
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   internet romantic  famrel  freetime  Dalc health absences  G1  G2  G3
# 0       no       no       4         3     1      3        4   0  11  11
# 1      yes       no       5         3     1      3        2   9  11  11
# 2      yes       no       4         3     2      3        6  12  13  12
# 3      yes      yes       3         2     1      5        0  14  14  14
# 4       no       no       4         3     1      5        0  11  13  13
#
# [5 rows x 31 columns]

# %%
students.drop(1, axis=0, inplace=True)

# %%
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
#
#    ... internet romantic  famrel  freetime  Dalc health absences  G1  G2  G3
# 0  ...       no       no       4         3     1      3        4   0  11  11
# 2  ...      yes       no       4         3     2      3        6  12  13  12
# 3  ...      yes      yes       3         2     1      5        0  14  14  14
# 4  ...       no       no       4         3     1      5        0  11  13  13
# 5  ...      yes       no       5         4     1      5        6  12  12  13
#
# [5 rows x 31 columns]

# %%
#funciones de agregacion como mean(). sirve para obtener medidas agrupadas por alguna caracteristica en este caso edad
students.groupby('age')['G1'].mean()
# Out:
# age
# 15    11.758929
# 16    11.723164
# 17    11.533708
# 18    11.200000
# 19     9.031250
# 20    10.333333
# 21     9.000000
# 22     7.000000
# Name: G1, dtype: float64

# %%
#si hay valores nullos llena esos valores con el valor que proveamos
# students['alguna columna vacia'].fillna('standard', inplace=True)

# %%
#sirve para renombrar columnas, indices, etc
students.rename(columns={'age': 'edad'}, inplace=True)

# %%
students.head()
# Out:
#   school sex  edad address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F    18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F    17       U     GT3       T     1     1  at_home     other
# 2     GP   F    15       U     LE3       T     1     1  at_home     other
# 3     GP   F    15       U     GT3       T     4     2   health  services
# 4     GP   F    16       U     GT3       T     3     3    other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        4   0  11  11
# 1  ...      5        3      3     1     1      3        2   9  11  11
# 2  ...      4        3      2     2     3      3        6  12  13  12
# 3  ...      3        2      2     1     1      5        0  14  14  14
# 4  ...      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
#Obtiene los valores unicos de una variable categorica
students['Fjob'].unique()
# Out:
# array(['teacher', 'other', 'services', 'health', 'at_home'], dtype=object)

# %%
#cuenta la cantidad de veces que cada nivel de una variable categorica aparece
students['Fjob'].value_counts()
# Out:
# other       366
# services    181
# at_home      42
# teacher      36
# health       23
# Name: Fjob, dtype: int64

# %%
#cuenta los valores no nulos.
students.count()
# Out:
# school        648
# sex           648
# edad          648
# address       648
# famsize       648
# Pstatus       648
# Medu          648
# Fedu          648
# Mjob          648
# Fjob          648
# reason        648
# guardian      648
# traveltime    648
# studytime     648
# failures      648
# schoolsup     648
# famsup        648
# paid          648
# activities    648
# nursery       648
# higher        648
# internet      648
# romantic      648
# famrel        648
# freetime      648
# Dalc          648
# health        648
# absences      648
# G1            648
# G2            648
# G3            648
# dtype: int64
