# %%
import simpy
import random

# %%
def cliente(env, nombre, servidores, tasa_servicio):
    """Proceso para un cliente que entra en la cola."""
    llegada = env.now
    print(f"{nombre} llegó a las {llegada:.2f}")
    
    with servidores.request() as req:
        yield req  # Espera un servidor disponible
        espera = env.now - llegada
        print(f"{nombre} es atendido tras esperar {espera:.4f} unidades de tiempo")
        
        # Tiempo de servicio (distribución exponencial)
        tiempo_servicio = random.expovariate(tasa_servicio)
        yield env.timeout(tiempo_servicio)
        print(f"{nombre} sale de la cola a las {env.now:.2f}")

# %%
def generar_clientes(env, tasa_llegada, tasa_servicio, servidores):
    """Genera clientes con tiempos de llegada exponenciales."""
    i = 0
    while True:
        yield env.timeout(random.expovariate(tasa_llegada))
        i += 1
        env.process(cliente(env, f"Cliente-{i}", servidores, tasa_servicio))

# %%
# Parámetros de la simulación
tasa_llegada = 10.0  # Tasa de llegada (media de 1 llegada por unidad de tiempo)
tasa_servicio = 1.2  # Tasa de servicio (media de 1.2 clientes atendidos por unidad de tiempo)
n_servidores = 3     # Número de servidores en paralelo
tiempo_simulacion = 10  # Tiempo total de simulación

# Crear el entorno de simulación
env = simpy.Environment()
servidores = simpy.Resource(env, capacity=n_servidores)

# Iniciar el proceso de generación de clientes
env.process(generar_clientes(env, tasa_llegada, tasa_servicio, servidores))

# Ejecutar la simulación
env.run(until=tiempo_simulacion)
# Out:
# Cliente-1 llegó a las 0.21
# Cliente-1 es atendido tras esperar 0.0000 unidades de tiempo
# Cliente-2 llegó a las 0.27
# Cliente-2 es atendido tras esperar 0.0000 unidades de tiempo
# Cliente-3 llegó a las 0.32
# Cliente-3 es atendido tras esperar 0.0000 unidades de tiempo
# Cliente-4 llegó a las 0.44
# Cliente-5 llegó a las 0.46
# Cliente-6 llegó a las 0.49
# Cliente-7 llegó a las 0.63
# Cliente-8 llegó a las 0.97
# Cliente-3 sale de la cola a las 1.06
# Cliente-4 es atendido tras esperar 0.6124 unidades de tiempo
# Cliente-9 llegó a las 1.29
# Cliente-10 llegó a las 1.39
# Cliente-11 llegó a las 1.43
# Cliente-12 llegó a las 1.47
# Cliente-13 llegó a las 1.51
# Cliente-14 llegó a las 1.53
# Cliente-15 llegó a las 1.53
# Cliente-16 llegó a las 1.58
# Cliente-17 llegó a las 1.64
# Cliente-18 llegó a las 1.74
# Cliente-19 llegó a las 1.76
# Cliente-20 llegó a las 1.94
# Cliente-21 llegó a las 1.94
# Cliente-22 llegó a las 1.95
# Cliente-1 sale de la cola a las 1.97
# Cliente-5 es atendido tras esperar 1.5069 unidades de tiempo
# Cliente-23 llegó a las 2.08
# Cliente-24 llegó a las 2.14
# Cliente-25 llegó a las 2.15
# Cliente-4 sale de la cola a las 2.26
# Cliente-6 es atendido tras esperar 1.7725 unidades de tiempo
# Cliente-26 llegó a las 2.55
# Cliente-27 llegó a las 2.65
# Cliente-28 llegó a las 2.66
# Cliente-29 llegó a las 2.76
# Cliente-5 sale de la cola a las 2.77
# Cliente-7 es atendido tras esperar 2.1369 unidades de tiempo
# Cliente-30 llegó a las 2.80
# Cliente-31 llegó a las 2.84
# Cliente-7 sale de la cola a las 2.85
# Cliente-8 es atendido tras esperar 1.8883 unidades de tiempo
# Cliente-32 llegó a las 2.96
# Cliente-33 llegó a las 2.99
# Cliente-34 llegó a las 3.10
# Cliente-35 llegó a las 3.25
# Cliente-36 llegó a las 3.29
# Cliente-37 llegó a las 3.35
# Cliente-2 sale de la cola a las 3.42
# Cliente-9 es atendido tras esperar 2.1269 unidades de tiempo
# Cliente-38 llegó a las 3.43
# Cliente-39 llegó a las 3.53
# Cliente-40 llegó a las 3.61
# Cliente-8 sale de la cola a las 3.62
# Cliente-10 es atendido tras esperar 2.2304 unidades de tiempo
# Cliente-41 llegó a las 3.71
# Cliente-10 sale de la cola a las 3.76
# Cliente-11 es atendido tras esperar 2.3292 unidades de tiempo
# Cliente-42 llegó a las 3.81
# Cliente-9 sale de la cola a las 4.01
# Cliente-12 es atendido tras esperar 2.5320 unidades de tiempo
# Cliente-6 sale de la cola a las 4.25
# Cliente-13 es atendido tras esperar 2.7443 unidades de tiempo
# Cliente-43 llegó a las 4.35
# Cliente-44 llegó a las 4.38
# Cliente-45 llegó a las 4.38
# Cliente-46 llegó a las 4.39
# Cliente-47 llegó a las 4.42
# Cliente-48 llegó a las 4.42
# Cliente-49 llegó a las 4.47
# Cliente-12 sale de la cola a las 4.57
# Cliente-14 es atendido tras esperar 3.0410 unidades de tiempo
# Cliente-50 llegó a las 4.60
# Cliente-51 llegó a las 4.64
# Cliente-52 llegó a las 4.67
# Cliente-53 llegó a las 4.88
# Cliente-54 llegó a las 4.94
# Cliente-11 sale de la cola a las 5.02
# Cliente-15 es atendido tras esperar 3.4839 unidades de tiempo
# Cliente-55 llegó a las 5.03
# Cliente-56 llegó a las 5.04
# Cliente-57 llegó a las 5.05
# Cliente-58 llegó a las 5.09
# Cliente-59 llegó a las 5.11
# Cliente-60 llegó a las 5.14
# Cliente-61 llegó a las 5.17
# Cliente-13 sale de la cola a las 5.18
# Cliente-16 es atendido tras esperar 3.6030 unidades de tiempo
# Cliente-62 llegó a las 5.19
# Cliente-63 llegó a las 5.29
# Cliente-64 llegó a las 5.30
# Cliente-65 llegó a las 5.32
# Cliente-15 sale de la cola a las 5.33
# Cliente-17 es atendido tras esperar 3.6895 unidades de tiempo
# Cliente-66 llegó a las 5.40
# Cliente-14 sale de la cola a las 5.43
# Cliente-18 es atendido tras esperar 3.6826 unidades de tiempo
# Cliente-67 llegó a las 5.47
# Cliente-68 llegó a las 5.48
# Cliente-69 llegó a las 5.60
# Cliente-70 llegó a las 5.73
# Cliente-71 llegó a las 5.76
# Cliente-72 llegó a las 5.91
# Cliente-73 llegó a las 5.94
# Cliente-74 llegó a las 5.96
# Cliente-75 llegó a las 6.00
# Cliente-76 llegó a las 6.05
# Cliente-77 llegó a las 6.16
# Cliente-78 llegó a las 6.17
# Cliente-79 llegó a las 6.17
# Cliente-80 llegó a las 6.19
# Cliente-81 llegó a las 6.23
# Cliente-16 sale de la cola a las 6.26
# Cliente-19 es atendido tras esperar 4.4975 unidades de tiempo
# Cliente-82 llegó a las 6.28
# Cliente-83 llegó a las 6.30
# Cliente-19 sale de la cola a las 6.36
# Cliente-20 es atendido tras esperar 4.4256 unidades de tiempo
# Cliente-84 llegó a las 6.51
# Cliente-85 llegó a las 6.54
# Cliente-18 sale de la cola a las 6.65
# Cliente-21 es atendido tras esperar 4.7104 unidades de tiempo
# Cliente-86 llegó a las 6.67
# Cliente-87 llegó a las 6.68
# Cliente-17 sale de la cola a las 6.72
# Cliente-22 es atendido tras esperar 4.7686 unidades de tiempo
# Cliente-21 sale de la cola a las 7.00
# Cliente-23 es atendido tras esperar 4.9260 unidades de tiempo
# Cliente-88 llegó a las 7.18
# Cliente-89 llegó a las 7.23
# Cliente-90 llegó a las 7.25
# Cliente-91 llegó a las 7.27
# Cliente-20 sale de la cola a las 7.33
# Cliente-24 es atendido tras esperar 5.1860 unidades de tiempo
# Cliente-92 llegó a las 7.34
# Cliente-93 llegó a las 7.42
# Cliente-94 llegó a las 7.55
# Cliente-24 sale de la cola a las 7.57
# Cliente-25 es atendido tras esperar 5.4116 unidades de tiempo
# Cliente-95 llegó a las 7.60
# Cliente-96 llegó a las 7.65
# Cliente-22 sale de la cola a las 7.71
# Cliente-26 es atendido tras esperar 5.1628 unidades de tiempo
# Cliente-26 sale de la cola a las 7.71
# Cliente-27 es atendido tras esperar 5.0586 unidades de tiempo
# Cliente-97 llegó a las 7.73
# Cliente-98 llegó a las 7.78
# Cliente-23 sale de la cola a las 7.78
# Cliente-28 es atendido tras esperar 5.1263 unidades de tiempo
# Cliente-99 llegó a las 7.79
# Cliente-100 llegó a las 7.87
# Cliente-101 llegó a las 7.89
# Cliente-102 llegó a las 7.92
# Cliente-25 sale de la cola a las 7.94
# Cliente-29 es atendido tras esperar 5.1801 unidades de tiempo
# Cliente-27 sale de la cola a las 7.94
# Cliente-30 es atendido tras esperar 5.1449 unidades de tiempo
# Cliente-103 llegó a las 8.01
# Cliente-104 llegó a las 8.16
# Cliente-105 llegó a las 8.16
# Cliente-106 llegó a las 8.20
# Cliente-107 llegó a las 8.20
# Cliente-108 llegó a las 8.30
# Cliente-109 llegó a las 8.33
# Cliente-110 llegó a las 8.35
# Cliente-111 llegó a las 8.36
# Cliente-29 sale de la cola a las 8.36
# Cliente-31 es atendido tras esperar 5.5149 unidades de tiempo
# Cliente-112 llegó a las 8.46
# Cliente-30 sale de la cola a las 8.47
# Cliente-32 es atendido tras esperar 5.5036 unidades de tiempo
# Cliente-113 llegó a las 8.50
# Cliente-114 llegó a las 8.52
# Cliente-115 llegó a las 8.55
# Cliente-32 sale de la cola a las 8.56
# Cliente-33 es atendido tras esperar 5.5743 unidades de tiempo
# Cliente-116 llegó a las 8.57
# Cliente-117 llegó a las 8.57
# Cliente-118 llegó a las 8.57
# Cliente-119 llegó a las 8.62
# Cliente-33 sale de la cola a las 8.70
# Cliente-34 es atendido tras esperar 5.6008 unidades de tiempo
# Cliente-120 llegó a las 8.75
# Cliente-121 llegó a las 8.91
# Cliente-122 llegó a las 9.00
# Cliente-123 llegó a las 9.03
# Cliente-34 sale de la cola a las 9.08
# Cliente-35 es atendido tras esperar 5.8276 unidades de tiempo
# Cliente-124 llegó a las 9.17
# Cliente-35 sale de la cola a las 9.19
# Cliente-36 es atendido tras esperar 5.9022 unidades de tiempo
# Cliente-125 llegó a las 9.33
# Cliente-31 sale de la cola a las 9.36
# Cliente-37 es atendido tras esperar 6.0118 unidades de tiempo
# Cliente-126 llegó a las 9.37
# Cliente-36 sale de la cola a las 9.58
# Cliente-38 es atendido tras esperar 6.1515 unidades de tiempo
# Cliente-127 llegó a las 9.63
# Cliente-128 llegó a las 9.66
# Cliente-129 llegó a las 9.66
# Cliente-130 llegó a las 9.73
# Cliente-28 sale de la cola a las 9.74
# Cliente-39 es atendido tras esperar 6.2150 unidades de tiempo
# Cliente-131 llegó a las 9.89

# %%
import pandas as pd

# %%
df = pd.read_csv("resultados_simulacion.csv")
df.head()
# Out:
#    ID de simulación Numero de cliente Hora de llegada  Tiempo entre llegada  \
# 0                 1         Cliente-1         0:00:51              0.000000
# 1                 1         Cliente-2         0:08:12            441.149342
# 2                 1         Cliente-3         0:11:46            214.342149
# 3                 1         Cliente-5         0:14:09             42.991368
# 4                 1         Cliente-4         0:13:26            100.301629
#
#    Tiempo de llegada  Tiempo en Cola Hora de inicio de servicio  \
# 0          50.559593             0.0                    0:00:51
# 1         491.708935             0.0                    0:08:12
# 2         706.051084             0.0                    0:11:46
# 3         849.344082             0.0                    0:14:09
# 4         806.352714             0.0                    0:13:26
#
#    Tiempo de servicio Hora de fin de servicio  Tiempo en el sistema  \
# 0          405.992194                 0:07:37            405.992194
# 1          154.428656                 0:10:46            154.428656
# 2           65.514403                 0:12:52             65.514403
# 3           89.599087                 0:15:39             89.599087
# 4          226.285430                 0:17:13            226.285430
#
#    Longitud del sistema  Longitud de la Cola
# 0                     0                    0
# 1                     0                    0
# 2                     0                    0
# 3                     1                    0
# 4                     0                    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935 entries, 0 to 934
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID de simulación            935 non-null    int64
#  1   Numero de cliente           935 non-null    object
#  2   Hora de llegada             935 non-null    object
#  3   Tiempo entre llegada        935 non-null    float64
#  4   Tiempo de llegada           935 non-null    float64
#  5   Tiempo en Cola              935 non-null    float64
#  6   Hora de inicio de servicio  935 non-null    object
#  7   Tiempo de servicio          935 non-null    float64
#  8   Hora de fin de servicio     935 non-null    object
#  9   Tiempo en el sistema        935 non-null    float64
#  10  Longitud del sistema        935 non-null    int64
#  11  Longitud de la Cola         935 non-null    int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 87.8+ KB

# %%
sum(df.loc[df["ID de simulación"] == 1,"Tiempo en Cola"])
# Out:
# 4565.449847890729

# %%
# Agrupar por ID de simulación
agrupado_por_simulacion = df.groupby('ID de simulación')

# Calcular métricas por simulación
resultados = agrupado_por_simulacion.agg(
    longitud_esperada_sistema=('Longitud del sistema', 'mean'),
    longitud_promedio_cola=('Longitud de la Cola', 'mean'),
    tiempo_total_espera=('Tiempo de servicio', 'sum'),
    tiempo_promedio_sistema=('Tiempo en el sistema', 'mean'),
    tiempo_total_cola=('Tiempo en Cola', 'sum'),
    promedio_tiempo_cola=('Tiempo en Cola', 'mean'),
    maxima_longitud_cola=('Longitud de la Cola', 'max')
).reset_index()

# %%
resultados.head()
# Out:
#    ID de simulación  longitud_esperada_sistema  longitud_promedio_cola  \
# 0                 1                   0.930233                0.069767
# 1                 2                   1.239583                0.260417
# 2                 3                   0.768116                0.101449
# 3                 4                   1.152941                0.247059
# 4                 5                   0.850746                0.179104
#
#    tiempo_total_espera  tiempo_promedio_sistema  tiempo_total_cola  \
# 0         27501.453794               372.870973        4565.449848
# 1         30703.057572               427.293586       10317.126681
# 2         21680.220403               356.785003        2937.944777
# 3         25215.650173               388.829703        7834.874602
# 4         22935.084891               423.434849        5435.050017
#
#    promedio_tiempo_cola  maxima_longitud_cola
# 0             53.086626                     1
# 1            107.470070                     3
# 2             42.578910                     2
# 3             92.174995                     4
# 4             81.120150                     3

# %% [markdown]
# # ¿Qué hace `SimPy` para simular el sistema de colas?
#
# La biblioteca `SimPy` es un marco para la simulación de eventos discretos en Python. En este caso, se utiliza para modelar un sistema de colas con múltiples servidores y clientes. A continuación, se detalla cómo `SimPy` facilita la simulación:
#
# ---
#
# ## **1. Modelado del tiempo**
#
# `SimPy` gestiona el tiempo de manera discreta, es decir, avanza el tiempo de simulación de un evento al siguiente. Esto permite simular procesos donde los eventos ocurren en momentos específicos (como llegadas de clientes o liberación de servidores).
#
# En el código:
# - `env.now`: Proporciona el tiempo actual en la simulación.
# - `env.timeout(t)`: Pausa el proceso por `t` unidades de tiempo, simulando el paso del tiempo entre eventos.
#
# ---
#
# ## **2. Creación de procesos**
#
# `SimPy` modela cada entidad (como un cliente) como un proceso independiente que realiza una serie de pasos. Estos procesos se definen como funciones generadoras en Python, donde `yield` se usa para ceder el control al entorno de simulación.
#
# En el código:
# - Cada cliente se modela como un proceso mediante la función `cliente`.
# - Los procesos de clientes se crean dinámicamente con `env.process()` y se gestionan en paralelo.
#
# ---
#
# ## **3. Gestión de recursos**
#
# `SimPy` permite modelar recursos con capacidad limitada, como servidores, máquinas o espacios de almacenamiento. Estos recursos controlan el acceso de los procesos y gestionan las colas cuando la capacidad está llena.
#
# En el código:
# - `simpy.Resource(env, capacity=n)`: Crea un recurso con una capacidad de `n` unidades (en este caso, los servidores).
# - `servidores.request()`: Simula que un cliente solicita acceso a un servidor.
# - `with servidores.request() as req`: Modelo de contexto para manejar la ocupación y liberación automática del recurso.
#
# ---
#
# ## **4. Simulación de distribuciones aleatorias**
#
# `SimPy` permite integrar distribuciones aleatorias, como la exponencial, para modelar la incertidumbre en los tiempos entre llegadas o los tiempos de servicio.
#
# En el código:
# - `random.expovariate(tasa)`: Genera valores aleatorios siguiendo una distribución exponencial, útil para modelar:
#   - Tiempos entre llegadas de clientes (`tasa_llegada`).
#   - Duración del servicio a un cliente (`tasa_servicio`).
#
# ---
#
# ## **5. Coordinación y ejecución de la simulación**
#
# `SimPy` se encarga de coordinar todos los procesos y eventos, avanzando el tiempo y ejecutando las acciones en el orden correcto.
#
# En el código:
# - `env.run(until=t)`: Ejecuta la simulación hasta el tiempo `t`, gestionando las interacciones entre los procesos y los recursos.
#
# ---
#
# En resumen, `SimPy` proporciona herramientas para modelar, coordinar y ejecutar simulaciones de eventos discretos, lo que permite analizar sistemas complejos como colas y tiempos de espera de forma eficiente y reproducible.
